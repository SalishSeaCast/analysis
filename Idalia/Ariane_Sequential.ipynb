# %% [markdown]
# ### Understanding the sequential function in Ariane

# %% [markdown]
# # Imports

# %%
import netCDF4 as NC
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.cm as cm
from IPython.core.display import Image
import datetime as dt


from salishsea_tools import (nc_tools,tidetools,viz_tools,stormtools)

# %matplotlib inline

# %% [markdown]
# # Data

# %%
grid = NC.Dataset('/ocean/imachuca/MEOPAR/NEMO-forcing/grid/bathy_meter_SalishSea2.nc','r')
bathy, X, Y = tidetools.get_bathy_data(grid)
lats = grid.variables['nav_lat']
lons = grid.variables['nav_lon']
bath = grid.variables['Bathymetry']

# %%
o1 = NC.Dataset('/ocean/imachuca/MEOPAR/Ariane/results/drifter_compare/oct8/drop3/1/ariane_trajectories_qualitative.nc','r')
lon1=o1.variables['traj_lon']
lat1=o1.variables['traj_lat']

# %%
o2 = NC.Dataset('/ocean/imachuca/MEOPAR/Ariane/results/drifter_compare/sequential/ariane_trajectories_qualitative.nc','r')
lon2=o2.variables['traj_lon']
lat2=o2.variables['traj_lat']

# %%
o3 = NC.Dataset('/ocean/imachuca/MEOPAR/Ariane/results/drifter_compare/sequential/diff_cycle/ariane_trajectories_qualitative.nc','r')
lon3=o3.variables['traj_lon']
lat3=o3.variables['traj_lat']

# %% [markdown]
# # Comparison

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(10, 8))
viz_tools.plot_coastline(ax1,grid,coords='map')
ax1.set_xlim([-123.6,-123])
ax1.set_ylim([48.6,49.4])
ax1.scatter(lon1[1:,:],lat1[1:,:],color='DodgerBlue',marker='o',label='Standard: no maxcycles')
ax1.scatter(lon1[0,:],lat1[0,:],color='red',marker='s')

ax1.scatter(lon2[1:,:],lat2[1:,:],color='Indigo',marker='o',label='Sequential: maxcycles=1')
ax1.scatter(lon2[0,:],lat2[0,:],color='red',marker='s')

ax1.scatter(lon3[1:,:],lat3[1:,:],color='MediumVioletRed',marker='o',label='Sequential: maxcycles=2')
ax1.scatter(lon3[0,:],lat3[0,:],color='red',marker='s')

ax1.legend()

ax1.set_title('October 8 Drifter')
