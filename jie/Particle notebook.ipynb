# %%
import netCDF4 as NC
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.cm as cm
from IPython.core.display import Image
import datetime as dt

from salishsea_tools import (nc_tools,tidetools,viz_tools,stormtools)

# %matplotlib inline

# %% [markdown]
# # Grid

# %%
grid = NC.Dataset('/ocean/imachuca/MEOPAR/NEMO-forcing/grid/bathy_meter_SalishSea2.nc','r')
bathy, X, Y = tidetools.get_bathy_data(grid)
lats = grid.variables['nav_lat']
lons = grid.variables['nav_lon']
bath = grid.variables['Bathymetry']

# %% [markdown]
# # Particle released Sept 20, 2014 at 20:30 UTC for 22 hours

# %%
seq = NC.Dataset('/ocean/imachuca/MEOPAR/Ariane/results/drifter_compare/sequential/ariane_trajectories_qualitative.nc','r')
lonseq=seq.variables['traj_lon']
latseq=seq.variables['traj_lat']
lonseq.shape
# Out:
# (23, 1)

# %%
fig,ax=plt.subplots(1,1,figsize=(6,6))

#particle plotting
ax.plot(lonseq,latseq, 'o',color='DodgerBlue')
ax.plot(lonseq[0],latseq[0],color='0.30',marker='s')

#bathymetry
viz_tools.plot_coastline(ax,grid,coords='map')
viz_tools.plot_coastline(ax,grid,isobath=4,color='FireBrick',coords='map') #4m isobath
viz_tools.plot_coastline(ax,grid,isobath=20,color='OrangeRed',coords='map') #20m isobath

#axis limtits
ax.set_xlim([-123.6,-122.6])
ax.set_ylim([48.8,49.4])

#labels
ax.annotate('Fraser River', xy=(-123.1,49.1), xytext=(-123,49.15),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )
ax.plot(-123.25,49.27,'r*',ms=15)
ax.annotate('UBC', xy=(-123.24,49.27), xytext=(-123.1,49.25),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )
