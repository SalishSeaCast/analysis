# %% [markdown]
# # Imports from research_ferries.py in my own directory

# %%
import sys
import scipy.io as sio

sys.path.append('/ocean/jieliu/research/meopar/salinity_comparison/')
import research_ferries as rf
# %matplotlib inline

# %%
fig = rf.salinity_ferry_route('HBDB')
# Out:
# /home/jieliu/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.py:1057: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if aspect == 'normal':
# /home/jieliu/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.py:1062: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   elif aspect in ('equal', 'auto'):

# %%
fig.savefig('HBDB.png')

# %%
fig = rf.salinity_ferry_route('TWSB')

# %%
fig.savefig('TWSB.png')

# %%
fig = rf.salinity_ferry_route('TWDP')

# %%
fig.savefig('TWDP.png')

# %% [markdown]
# # Import from research_ferries.py in nowcast directory

# %%
from salishsea_tools import tidetools,bathy_tools,viz_tools
from salishsea_tools.nowcast import research_ferries 
# %matplotlib inline

# %%
fig =research_ferries.salinity_ferry_route('TWSB')
# Out:
# /home/jieliu/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.py:1057: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if aspect == 'normal':
# /home/jieliu/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.py:1062: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   elif aspect in ('equal', 'auto'):

# %%
fig = research_ferries.salinity_ferry_route('TWDP')

# %%
fig = research_ferries.salinity_ferry_route('HBDB')
