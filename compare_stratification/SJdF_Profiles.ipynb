# %% [markdown]
# Notebook to compare Strait of Juan de Fuca model salinity with IOS data collected in 2013.
#
# IOS data stored in:
# /ocean/sallen/allen/research/MEOPAR/IOS_2003_CTD/2003-07/CTD

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import netCDF4 as nc
import os
import datetime
import glob

from salishsea_tools import viz_tools
from salishsea_tools import tidetools
from salishsea_tools import nc_tools

# %%
def read_IOS_file(filename,i_stn):
    filehandle = open(filename,'rt')
    with filehandle as data:
            headerover = False
            for line in data:
                if headerover:
                    word = line.split()
                    ss_depth[i_stn,count[i_stn]] = float(word[0])
                    ss_sal[i_stn,count[i_stn]] = float(word[5])
                    ss_temp[i_stn,count[i_stn]] = float(word[1])
                    count[i_stn] = count[i_stn] + 1
                elif line[0:14] == "*END OF HEADER":
                    headerover = True
                else:
                    word = line.split()
                    if len(word) > 1:
                        if word[0] == "LATITUDE":
                            lat = float(word[2])+ float(word[3])/60
                            lats[i_stn]=lat
                        if word[0] == "LONGITUDE":
                            lon = -(float(word[2])+ float(word[3])/60)
                            lons[i_stn]=lon
                        if word[0] == "START":
                            string = word[4] +' ' + word[5]
                            time = datetime.datetime.strptime(string,'%Y/%m/%d %H:%M:%S.%f')
                            times.append(time)
    return lat,lon,time

# %% [markdown]
# Quick look at the files locations and times. Are the all on the same day, how close together are they?

# %%
files =glob.glob('/ocean/sallen/allen/research/MEOPAR/IOS_2003_CTD/2003-07/CTD/*')
files.sort(key=os.path.basename)
#initilize arrays
nsamps=len(files) #number of samples
ss_depth = np.empty((nsamps,500)); ss_depth.fill('NaN')
ss_sal = np.empty((nsamps,500)); ss_sal.fill('NaN')
ss_temp = np.empty((nsamps,500)); ss_temp.fill('NaN')
count = np.zeros((nsamps), dtype=np.int)
lats=np.zeros(nsamps); lons=np.zeros(nsamps); times=[]
i_stn=0
#Loop through files
for filename in files:
    lat,lon,time=read_IOS_file(filename,i_stn)
    i_stn=i_stn+1
    print lat,lon,time
times=np.array(times)
# Out:
# 48.63 -123.243 2003-04-24 01:05:21
# 48.5651666667 -123.211666667 2003-04-24 02:01:32
# 48.4236666667 -124.752833333 2003-04-24 11:29:04
# 48.5003333333 -124.7345 2003-04-24 13:05:26
# 48.5498333333 -124.713833333 2003-04-24 13:57:39
# 48.5233333333 -124.498833333 2003-04-24 15:02:30
# 48.4691666667 -124.547333333 2003-04-24 15:54:58
# 48.4191666667 -124.595666667 2003-04-24 17:05:25
# 48.2488333333 -124.112333333 2003-04-24 19:37:04
# 48.31 -124.067166667 2003-04-24 20:41:03
# 48.3696666667 -123.990833333 2003-04-24 21:34:24
# 48.32 -123.720166667 2003-04-24 22:57:34
# 48.2595 -123.721 2003-04-24 23:31:13
# 48.2033333333 -123.716666667 2003-04-25 00:11:59
# 48.183 -123.316833333 2003-04-25 02:14:30
# 48.1828333333 -123.316666667 2003-04-25 02:20:38
# 48.2331666667 -123.300833333 2003-04-25 02:51:16
# 48.3331666667 -123.2985 2003-04-25 03:43:19
# 48.3805 -123.301 2003-04-25 04:22:34
# 48.322 -123.234 2003-04-25 05:02:17
# 48.2651666667 -123.162666667 2003-04-25 05:38:55
# 48.214 -123.096166667 2003-04-25 06:20:36
# 48.2435 -122.974833333 2003-04-25 06:59:40
    dinds = np.where(np.logical_and(depth_m[:]>=d1,depth_m[:]<=d2))
    dinds = dinds[0]
    
    #Loop through obervations. For ones on date, plot salinity vs longitude for obs and model.
    sal_model=[];sal_obs=[]; lon_plotm=[]; lon_ploto=[]
    for n in range(times.shape[0]):
        if times[n].day == date.day:
            # model data
            [j,i]=tidetools.find_closest_model_point(lons[n],lats[n],X,Y,bathy,allow_land=False)
            if not isinstance(j,list): #check in domain
                sal_plot=sal_m[tind,dinds,j,i]
                #mask so that I don't integrate over zeros
                mu=sal_plot==0; sal_plot=np.ma.array(sal_plot,mask=mu)
                dz=np.ma.array(depth_m[dinds],mask=mu); model_range=np.ptp(dz);
                #average
                print ' Model depth range: {} m'.format(model_range)
                sal_plot=np.trapz(sal_plot,x=dz)/model_range
                sal_model.append(sal_plot);lon_plotm.append(lons[n])   
            #observations data
            obs_dinds=np.where(np.logical_and(ss_depth[n,:]>=d1,ss_depth[n,:]<=d2))
            dz=np.array(ss_depth[n,obs_dinds])
            if dz.size ==0: #check there are any observations in this depth range
                obs_plot='Nan'
            else:
                obs_range=np.ptp(dz)
                print ' Observed depth range: {} m'.format(obs_range)
                obs_plot=np.trapz(ss_sal[n,obs_dinds],x=dz)/np.ptp(dz)
            sal_obs.append(obs_plot); lon_ploto.append(lons[n])

    #sorting so plot in a line along longitude
    model_sort = [x for y, x in sorted(zip(lon_plotm, sal_model))]
    lon_plotm.sort()
    obs_sort = [x for y, x in sorted(zip(lon_ploto, sal_obs))]
    lon_ploto.sort()
    
    #plot
    ax.plot(lon_plotm,model_sort,'bo-',label='Model')
    ax.plot(lon_ploto,obs_sort,'rs-',label='Observation')
    ax.legend(loc=0)
    ax.set_xlabel('Salinity [psu]'); ax.set_ylabel('Longitude')
    ax.set_title('Salinity on {date} averaged over {d1} - {d2} m'.format(date=date.strftime('%Y/%m/%d'),d1=d1,d2=d2))
    #ax.set_ylim([smin,smax])
    ax.set_xlim([-125,-122.3])
    
    return fig

# %%
path='/ocean/dlatorne/MEOPAR/SalishSea/results/spin-up/21apr30apr/SalishSea_1d_20030421_20030430_grid_T.nc'
gridT=nc.Dataset(path)
sal_m = gridT.variables['vosaline']
temp_m=gridT.variables['votemper']
depth_m=gridT.variables['deptht']

grid_B = nc.Dataset('/data/nsoontie/MEOPAR/NEMO-forcing/grid/bathy_meter_SalishSea2.nc')
bathy, X, Y = tidetools.get_bathy_data(grid_B)

# %% [markdown]
# Plots for each day below. Be aware that the vertical axis limits changes with date.

# %% [markdown]
# # April 24, 2003

# %%
d1s=[0,5,10,50]; d2s=[5,10,50,100]
for d1,d2 in zip(d1s,d2s):
    print 'Desired depth range: {:.2f} m'.format(d2-d1)
    fig=compare_salinity(d1,d2,datetime.datetime(2003,4,24),smin=28,smax=34)
# Out:
# Desired depth range: 5.00 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.9 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.1 m
#  Observed depth range: 3.6 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 2.6 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 2.8 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.1 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.5 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 2.9 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.0 m
#  Observed depth range: 3.7 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 4.6 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 2.8 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.0 m
# Desired depth range: 5.00 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
# Desired depth range: 40.00 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Observed depth range: 39.9 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 39.7 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 39.6 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Observed depth range: 39.9 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
# Desired depth range: 50.00 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Observed depth range: 49.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 49.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 49.0 m
#  Model depth range: 18.1012535095 m
#  Observed depth range: 39.7 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Observed depth range: 49.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m

# %% [markdown]
# # April 25, 2003

# %%
d1s=[0,5,10,50]; d2s=[5,10,50,100]
for d1,d2 in zip(d1s,d2s):
    print 'Desired depth range: {:.2f} m'.format(d2-d1)
    fig=compare_salinity(d1,d2,datetime.datetime(2003,4,25),smin=24,smax=34)
# Out:
# Desired depth range: 5.00 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 2.0 m
#  Observed depth range: 3.7 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.0 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 1.9 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 2.6 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.0 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.1 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 2.6 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 2.8 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 2.7 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 2.7 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 4.0 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 2.8 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.0 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 4.1 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.7 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 2.8 m
#  Observed depth range: 2.7 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 1.6 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.8 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 4.0 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.7 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 4.6 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 2.9 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.7 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 1.9 m
# Desired depth range: 5.00 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
# Desired depth range: 40.00 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 17.725151062 m
#  Observed depth range: 11.2 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
# Desired depth range: 50.00 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Observed depth range: 30.0 m
#  Model depth range: 18.1012535095 m
#  Observed depth range: 21.7 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 49.0 m
#  Model depth range: 18.1012535095 m
#  Observed depth range: 16.6 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 42.7 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 42.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 47.7 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 18.1012535095 m
#  Observed depth range: 21.9 m
#  Model depth range: -- m
#  Observed depth range: 0.5 m
#  Model depth range: 18.1012535095 m
#  Observed depth range: 23.7 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: -- m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
# /home/nsoontie/anaconda/lib/python2.7/site-packages/numpy/ma/core.py:3895: UserWarning: Warning: converting a masked element to nan.
#   warnings.warn("Warning: converting a masked element to nan.")

# %% [markdown]
# # April 26, 2003

# %%
d1s=[0,5,10,50]; d2s=[5,10,50,100]
for d1,d2 in zip(d1s,d2s):
    fig=compare_salinity(d1,d2,datetime.datetime(2003,4,26),smin=15,smax=32)
# Out:
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.0 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 2.6 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 1.7 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 2.8 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.5 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 2.8 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.6 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.7 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 4.5 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.0 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.6 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.7 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.0 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.0 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.7 m
#  Observed depth range: 2.0 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 2.9 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.8 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.6 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.0 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 2.9 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 1.8 m
#  Observed depth range: 2.7 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 2.7 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 39.5 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m

# %% [markdown]
# # April 27, 2003

# %%
d1s=[0,5,10,50]; d2s=[5,10,50,100]
for d1,d2 in zip(d1s,d2s):
    print 'Desired depth range: {:.2f} m'.format(d2-d1)
    fig=compare_salinity(d1,d2,datetime.datetime(2003,4,27),smin=22,smax=32)
# Out:
# Desired depth range: 5.00 m
#  Observed depth range: 1.7 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 2.7 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 2.0 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 2.6 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 2.6 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 2.8 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 0.6 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.0 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.9 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 2.8 m
#  Model depth range: 4.00007009506 m
#  Observed depth range: 3.7 m
# Desired depth range: 5.00 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
#  Model depth range: 4.00228214264 m
#  Observed depth range: 5.0 m
# Desired depth range: 40.00 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 17.725151062 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
#  Model depth range: 34.0129585266 m
#  Observed depth range: 40.0 m
# Desired depth range: 50.00 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: -- m
#  Observed depth range: 36.8 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m
#  Model depth range: 39.5786247253 m
#  Observed depth range: 50.0 m

# %% [markdown]
# I need to take a closer look before I decide what is going on here. Sometimes the model is too fresh and sometimes too salty. Where is it too fresh? Is it an assue to compare daily averages with instantaneous measurement?. Need some kind of a map that has more detail than longitude. Also, I should check the coding to make sure that I am not averaging over the 0 masks.
#
# Depth ranges for the model and observations are slightly different. Does this matter? Is there a better way to do this comparison?
#
# Any ways to improve the plots? Map with coordintes plotted beside each image? Or a map with dots coloured to salinity values?
