# %%
import netCDF4 as nc
from salishsea_tools import nc_tools
import matplotlib.pyplot as plt
import numpy as np
import os

# %matplotlib inline

resultsDir='/data/eolson/MEOPAR/SS2D/run3/'

# %%
fname='SalishSea_1h_20020915_20020916_ptrc_T.nc'
f=nc.Dataset(os.path.join(resultsDir,fname))
lons=f.variables['nav_lon'][1,:]
lats=f.variables['nav_lat'][:,1]
z=f.variables['deptht'][:]

xx,zz=np.meshgrid(lons,-z[:])
xt,yt=np.meshgrid(lons,lats)

# %%
fkeys=f.variables.keys()
print fkeys
# Out:
# [u'nav_lon', u'nav_lat', u'deptht', u'time_counter', u'time_counter_bnds', u'DIC', u'Alkalini', u'O2', u'CaCO3', u'PO4', u'POC', u'Si', u'PHY', u'ZOO', u'DOC', u'PHY2', u'ZOO2', u'DSi', u'Fer', u'BFe', u'GOC', u'SFe', u'DFe', u'GSi', u'NFe', u'NCHL', u'DCHL', u'NO3', u'NH4']

# %%
# loop  through variables and plot them each in a figure
#var1=np.copy(f.variables['DIC'])
# Alk
ikey=fkeys[6]
if np.ndim(f.variables[ikey])==4:
    ivar=f.variables[ikey][:,:,:,:]
    #ivmin=np.amin(ivar)
    #ivmax=np.amax(ivar)
    ivmin=2420
    ivmax=2424
    fig, axs = plt.subplots(6,1,figsize=(15,20))

    mesh0=axs[0].pcolormesh(xt,yt,ivar[0,0,:,:],vmin=ivmin,vmax=ivmax)
    axs[0].set_title('Surface Alk, t =1 hr')
    fig.colorbar(mesh0,ax=axs[0])

    mesh1=axs[1].pcolormesh(xt,yt,ivar[ivar.shape[0]-1,0,:,:],vmin=ivmin,vmax=ivmax)
    axs[1].set_title('Surface Alk, t = 2 days')
    fig.colorbar(mesh1,ax=axs[1])

    mesh2=axs[2].pcolormesh(xx,zz,ivar[0,:,4,:],vmin=ivmin,vmax=ivmax)
    axs[2].set_title('Alk, t = 1 hr')
    fig.colorbar(mesh2,ax=axs[2])

    mesh3=axs[3].pcolormesh(xx,zz,ivar[ivar.shape[0]-1,:,4,:],vmin=ivmin,vmax=ivmax)
    axs[3].set_title('Alk, t = 2 days')
    fig.colorbar(mesh3,ax=axs[3])
    
    mesh4=axs[4].pcolormesh(xt,yt,ivar[ivar.shape[0]-1,0,:,:]-ivar[1,0,:,:],vmin=-1,vmax=1)
    axs[4].set_title('Surface Alk, Diff')
    fig.colorbar(mesh4,ax=axs[4])
    
    mesh5=axs[5].pcolormesh(xx,zz,ivar[ivar.shape[0]-1,:,4,:]-ivar[1,:,4,:],vmin=-1,vmax=1)
    axs[5].set_title('Alk, Diff')
    fig.colorbar(mesh5,ax=axs[5])

# %%
# DIC
ikey=fkeys[5]
if np.ndim(f.variables[ikey])==4:
    ivar=f.variables[ikey][:,:,:,:]
    #ivmin=np.amin(ivar)
    #ivmax=np.amax(ivar)
    ivmin=2300
    ivmax=2316
    fig, axs = plt.subplots(6,1,figsize=(15,20))

    mesh0=axs[0].pcolormesh(xt,yt,ivar[0,0,:,:],vmin=ivmin,vmax=ivmax)
    axs[0].set_title('Surface DIC, t =1 hr')
    fig.colorbar(mesh0,ax=axs[0])

    mesh1=axs[1].pcolormesh(xt,yt,ivar[ivar.shape[0]-1,0,:,:],vmin=ivmin,vmax=ivmax)
    axs[1].set_title('Surface DIC, t = 2 days')
    fig.colorbar(mesh1,ax=axs[1])

    mesh2=axs[2].pcolormesh(xx,zz,ivar[0,:,4,:],vmin=ivmin,vmax=ivmax)
    axs[2].set_title('DIC, t = 1 hr')
    fig.colorbar(mesh2,ax=axs[2])

    mesh3=axs[3].pcolormesh(xx,zz,ivar[ivar.shape[0]-1,:,4,:],vmin=ivmin,vmax=ivmax)
    axs[3].set_title('DIC, t = 2 days')
    fig.colorbar(mesh3,ax=axs[3])
    
    mesh4=axs[4].pcolormesh(xt,yt,ivar[ivar.shape[0]-1,0,:,:]-ivar[1,0,:,:],vmin=-8,vmax=8)
    axs[4].set_title('Surface DIC, Diff')
    fig.colorbar(mesh4,ax=axs[4])
    
    mesh5=axs[5].pcolormesh(xx,zz,ivar[ivar.shape[0]-1,:,4,:]-ivar[1,:,4,:],vmin=-.1,vmax=.1)
    axs[5].set_title('DIC, Diff')
    fig.colorbar(mesh5,ax=axs[5])

# %%
# PO4
ikey=fkeys[9]
if np.ndim(f.variables[ikey])==4:
    ivar=f.variables[ikey][:,:,:,:]
    #ivmin=np.amin(ivar[np.where(ivar!=0)])
    #ivmax=np.amax(ivar[np.where(ivar!=0)])
    ivmin=2.15
    ivmax=2.2
    fig, axs = plt.subplots(6,1,figsize=(15,20))

    mesh0=axs[0].pcolormesh(xt,yt,ivar[0,0,:,:],vmin=ivmin,vmax=ivmax)
    axs[0].set_title('Surface PO4, t =1 hr')
    fig.colorbar(mesh0,ax=axs[0])

    mesh1=axs[1].pcolormesh(xt,yt,ivar[ivar.shape[0]-1,0,:,:],vmin=ivmin,vmax=ivmax)
    axs[1].set_title('Surface PO4, t = 2 days')
    fig.colorbar(mesh1,ax=axs[1])

    mesh2=axs[2].pcolormesh(xx,zz,ivar[0,:,4,:],vmin=ivmin,vmax=ivmax)
    axs[2].set_title('PO4, t = 1 hr')
    fig.colorbar(mesh2,ax=axs[2])

    mesh3=axs[3].pcolormesh(xx,zz,ivar[ivar.shape[0]-1,:,4,:],vmin=ivmin,vmax=ivmax)
    axs[3].set_title('PO4, t = 2 daysr')
    fig.colorbar(mesh3,ax=axs[3])
    
    mesh4=axs[4].pcolormesh(xt,yt,ivar[ivar.shape[0]-1,0,:,:]-ivar[1,0,:,:],vmin=-.00001,vmax=.00001)
    axs[4].set_title('Surface PO4, Diff')
    fig.colorbar(mesh4,ax=axs[4])
    
    mesh5=axs[5].pcolormesh(xx,zz,ivar[ivar.shape[0]-1,:,4,:]-ivar[1,:,4,:],vmin=-.00001,vmax=.00001)
    axs[5].set_title('PO4, Diff')
    fig.colorbar(mesh5,ax=axs[5])

# %%
# NO3
ikey=fkeys[27]
if np.ndim(f.variables[ikey])==4:
    ivar=f.variables[ikey][:,:,:,:]
    #ivmin=np.amin(ivar[np.where(ivar!=0)])
    #ivmax=np.amax(ivar[np.where(ivar!=0)])
    ivmin=28
    ivmax=32
    fig, axs = plt.subplots(6,1,figsize=(15,20))

    mesh0=axs[0].pcolormesh(xt,yt,ivar[0,0,:,:],vmin=ivmin,vmax=ivmax)
    axs[0].set_title('Surface NO3, t =1 hr')
    fig.colorbar(mesh0,ax=axs[0])

    mesh1=axs[1].pcolormesh(xt,yt,ivar[ivar.shape[0]-1,0,:,:],vmin=ivmin,vmax=ivmax)
    axs[1].set_title('Surface NO3, t = 2 days')
    fig.colorbar(mesh1,ax=axs[1])

    mesh2=axs[2].pcolormesh(xx,zz,ivar[0,:,4,:],vmin=ivmin,vmax=ivmax)
    axs[2].set_title('NO3, t = 1 hr')
    fig.colorbar(mesh2,ax=axs[2])

    mesh3=axs[3].pcolormesh(xx,zz,ivar[ivar.shape[0]-1,:,4,:],vmin=ivmin,vmax=ivmax)
    axs[3].set_title('NO3, t = 2 daysr')
    fig.colorbar(mesh3,ax=axs[3])
    
    mesh4=axs[4].pcolormesh(xt,yt,ivar[ivar.shape[0]-1,0,:,:]-ivar[1,0,:,:],vmin=-.001,vmax=.001)
    axs[4].set_title('Surface NO3, Diff')
    fig.colorbar(mesh4,ax=axs[4])
    
    mesh5=axs[5].pcolormesh(xx,zz,ivar[ivar.shape[0]-1,:,4,:]-ivar[1,:,4,:],vmin=-.001,vmax=.001)
    axs[5].set_title('NO3, Diff')
    fig.colorbar(mesh5,ax=axs[5])

# %%
# PHY
ikey=fkeys[12]
if np.ndim(f.variables[ikey])==4:
    ivar=f.variables[ikey]
    #ivmin=np.amin(ivar[np.where(ivar!=0)])
    #ivmax=np.amax(ivar[np.where(ivar!=0)])
    ivmin=.009
    ivmax=.011
    fig, axs = plt.subplots(6,1,figsize=(15,20))

    mesh0=axs[0].pcolormesh(xt,yt,ivar[0,0,:,:],vmin=ivmin,vmax=ivmax)
    axs[0].set_title('Surface PHY, t =1 hr')
    fig.colorbar(mesh0,ax=axs[0])

    mesh1=axs[1].pcolormesh(xt,yt,ivar[ivar.shape[0]-1,0,:,:],vmin=ivmin,vmax=ivmax)
    axs[1].set_title('Surface PHY, t = 2 days')
    fig.colorbar(mesh1,ax=axs[1])

    mesh2=axs[2].pcolormesh(xx,zz,ivar[0,:,4,:],vmin=ivmin,vmax=ivmax)
    axs[2].set_title('PHY, t = 1 hr')
    fig.colorbar(mesh2,ax=axs[2])

    mesh3=axs[3].pcolormesh(xx,zz,ivar[ivar.shape[0]-1,:,4,:],vmin=ivmin,vmax=ivmax)
    axs[3].set_title('PHY, t = 2 days')
    fig.colorbar(mesh3,ax=axs[3])
    
    mesh4=axs[4].pcolormesh(xt,yt,ivar[ivar.shape[0]-1,0,:,:]-ivar[1,0,:,:],vmin=-.0000001,vmax=.0000001)
    axs[4].set_title('Surface PHY, Diff')
    fig.colorbar(mesh4,ax=axs[4])
    
    mesh5=axs[5].pcolormesh(xx,zz,ivar[ivar.shape[0]-1,:,4,:]-ivar[1,:,4,:],vmin=-.0000001,vmax=.0000001)
    axs[5].set_title('PHY, Diff')
    fig.colorbar(mesh5,ax=axs[5])

# %%
# ZOO
ikey=fkeys[13]
if np.ndim(f.variables[ikey])==4:
    ivar=f.variables[ikey]
    #ivmin=np.amin(ivar[np.where(ivar!=0)])
    #ivmax=np.amax(ivar[np.where(ivar!=0)])
    ivmin=.009
    ivmax=.011
    fig, axs = plt.subplots(6,1,figsize=(15,20))

    mesh0=axs[0].pcolormesh(xt,yt,ivar[0,0,:,:],vmin=ivmin,vmax=ivmax)
    axs[0].set_title('Surface ZOO, t =1 hr')
    fig.colorbar(mesh0,ax=axs[0])

    mesh1=axs[1].pcolormesh(xt,yt,ivar[ivar.shape[0]-1,0,:,:],vmin=ivmin,vmax=ivmax)
    axs[1].set_title('Surface ZOO, t = 2 days')
    fig.colorbar(mesh1,ax=axs[1])

    mesh2=axs[2].pcolormesh(xx,zz,ivar[0,:,4,:],vmin=ivmin,vmax=ivmax)
    axs[2].set_title('ZOO, t = 1 hr')
    fig.colorbar(mesh2,ax=axs[2])

    mesh3=axs[3].pcolormesh(xx,zz,ivar[ivar.shape[0]-1,:,4,:],vmin=ivmin,vmax=ivmax)
    axs[3].set_title('ZOO, t = 2 days')
    fig.colorbar(mesh3,ax=axs[3])
    
    mesh4=axs[4].pcolormesh(xt,yt,ivar[ivar.shape[0]-1,0,:,:]-ivar[1,0,:,:],vmin=-.0000001,vmax=.0000001)
    axs[4].set_title('Surface ZOO, Diff')
    fig.colorbar(mesh4,ax=axs[4])
    
    mesh5=axs[5].pcolormesh(xx,zz,ivar[ivar.shape[0]-1,:,4,:]-ivar[1,:,4,:],vmin=-.0000001,vmax=.0000001)
    axs[5].set_title('ZOO, Diff')
    fig.colorbar(mesh5,ax=axs[5])

# %%
f.close()

# %%
fname='SalishSea_1h_20020915_20020916_grid_T.nc'
f=nc.Dataset(os.path.join(resultsDir,fname))
lons=f.variables['nav_lon'][1,:]
lats=f.variables['nav_lat'][:,1]
z=f.variables['deptht'][:]

xx,zz=np.meshgrid(lons,-z[:])
xt,yt=np.meshgrid(lons,lats)

fkeys=f.variables.keys()
print fkeys
# Out:
# [u'nav_lon', u'nav_lat', u'deptht', u'time_counter', u'time_counter_bnds', u'sossheig', u'votemper', u'vosaline', u'rain_rate', u'snow_rate']

# %%
print f.variables['votemper'].standard_name
# Out:
# temperature
