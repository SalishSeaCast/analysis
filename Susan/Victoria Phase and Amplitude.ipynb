# %%
# imports
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

from __future__ import division

# %%
pha_diff = {'ene': 86,
           'wHoll': 87,
           'llap': 87,
           'wslip': 87,
           'TS4': 86,
           'smooth': 58,
           'downto2': 82,
            'downto5': 83,
           'weaklog': 89,
           'd10': 85,
           'u20': 86,
           'topog1': 80,
           'base': 91,
           'stronglog': 101,
           'secondlog': 96,
           'sticky': 90,
           'deep' : 55,
           'deep_fric': 83,
           'GmO': 75}
amp = {'ene': 0.25,
      'wHoll': 0.255,
      'llap': 0.29,
      'wslip': 0.27,
      'TS4': 0.26,
      'smooth': 0.18,
      'downto2': 0.24,
       'downto5': 0.24,
      'weaklog': 0.3,
      'd10': 0.255,
      'u20': 0.26,
      'topog1': 0.28,
      'base': 0.33,
      'stronglog': 0.49,
      'secondlog': 0.39,
      'sticky': 0.40,
      'deep': 0.19,
      'deep_fric': 0.34,
      'GmO': 0.36}

# %%
count = 0
fig, ax = plt.subplots(1,1,figsize=(9,9))
for key in pha_diff:
    count += 1
    if count <= 7:
        symbol = 'o'
    elif count <=14:
        symbol = '^'
    else:
        symbol = '>'
    ax.plot(pha_diff[key], amp[key], symbol, label=key)
ax.plot(75,0.37,'s',label='Obs')
ax.plot(92,0.33,'*',label='corr15')
ax.set_xlim((33,105))
ax.legend(loc='upper left')
ax.set_ylabel('Amplitude at Victoria (m)')
ax.set_xlabel('Phase difference Victoria to Pt Atkinson (deg)')

# %%
print (pha_diff['smooth'] 
       - pha_diff['wslip'] + pha_diff['llap'] 
       - pha_diff['downto2'] + pha_diff['llap'] 
       + pha_diff['secondlog'] - pha_diff['weaklog'] 
    )
print (amp['smooth'] 
       - amp['wslip'] + amp['llap'] 
       - amp['downto2'] + amp['llap'] 
       + amp['secondlog'] - amp['weaklog'] 
        )
# Out:
# 70
# 0.3399999999999999
