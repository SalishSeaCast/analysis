# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cdmin = 2.e-3

# %%
kappa = 0.4
zb = 0.0015
z = np.arange(2, 20, 0.5)
Cdleft0 = (1/kappa*np.log(z/(2*zb)))**(-2)
plt.plot(z,Cdleft0)
plt.plot(z,cdmin*np.ones_like(z),'o-')

# %%
zb = 3.5e-3*100
Cdleft = (1/kappa*np.log(z/(2*zb)))**(-2)
plt.plot(z,Cdleft,'b', z, Cdleft0,'r')
# Out:
# [<matplotlib.lines.Line2D at 0x7fc1275a1150>,
#  <matplotlib.lines.Line2D at 0x7fc12764c890>]
