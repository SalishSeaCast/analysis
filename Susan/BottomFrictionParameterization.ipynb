# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cdmin = 0.013

# %%
kappa = 0.4
zb = 0.3
z = np.arange(2, 20, 0.5)
Cdleft0 = (1/kappa*np.log(z/(2*zb)))**(-2)
plt.plot(z,Cdleft0)
plt.plot(z,cdmin*np.ones_like(z),'-')
plt.ylim((0.005, 0.10))
# Out:
# (0.005, 0.1)

# %%
zb = 3.5e-3*100
Cdleft = (1/kappa*np.log(z/(2*zb)))**(-2)
plt.plot(z,Cdleft,'b', z, Cdleft0,'r')
# Out:
# [<matplotlib.lines.Line2D at 0x7fa8c67b8d68>,
#  <matplotlib.lines.Line2D at 0x7fa8c67bd0f0>]
