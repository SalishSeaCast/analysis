# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cdmin = 1.e-2

# %%
kappa = 0.4
zb = 0.2
z = np.arange(2, 20, 0.5)
Cdleft0 = (1/kappa*np.log(z/(2*zb)))**(-2)
plt.plot(z,Cdleft0)
plt.plot(z,cdmin*np.ones_like(z),'o-')

# %%
zb = 3.5e-3*100
Cdleft = (1/kappa*np.log(z/(2*zb)))**(-2)
plt.plot(z,Cdleft,'b', z, Cdleft0,'r')
# Out:
# [<matplotlib.lines.Line2D at 0x7ff1e4107c10>,
#  <matplotlib.lines.Line2D at 0x7ff1e4107e90>]
