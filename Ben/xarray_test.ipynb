# %%
import netCDF4 as nc
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import warnings
import datetime as dtm
import vel_tools as vt
import xarray as xr
import cartopy.crs as ccrs

from salishsea_tools import nc_tools, viz_tools

# %matplotlib inline
mpl.rcParams.update({'font.size': 12})
mpl.rcParams["axes.formatter.useoffset"] = False

# %%
grid    = xr.open_dataset('https://salishsea.eos.ubc.ca/erddap/griddap/ubcSSnBathymetry2V1')
tracers = xr.open_dataset('https://salishsea.eos.ubc.ca/erddap/griddap/ubcSSn3DTracerFields1hV1')
u_vel   = xr.open_dataset('https://salishsea.eos.ubc.ca/erddap/griddap/ubcSSn3DuVelocity1hV1')
v_vel   = xr.open_dataset('https://salishsea.eos.ubc.ca/erddap/griddap/ubcSSn3DvVelocity1hV1')
w_vel   = xr.open_dataset('https://salishsea.eos.ubc.ca/erddap/griddap/ubcSSn3DwVelocity1hV1')

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
u_vel.uVelocity.sel(time='2016-02-01 00:00:00', depth=0, method='nearest').plot()
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 15))
u_vel.uVelocity.sel(time='2016-01', gridX=266, gridY=424).plot()
plt.show()
